# %% [markdown]
# <h1> AWS and Machine Learning </h1>

# %% [markdown]
# > Data Cleaning - Strategies for Missing Values - Advanced Imputation Strategy- MICE

# %% [markdown]
# GitHub Link: https://github.com/data-analytics-professionals

# %%
# Set the Jyputer Notebook, width: 100% 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from IPython.display import Image
cover = Image(filename="../project_diabetes/photos/036-AdvancedImputationTechnique-MICE.jpg")
display(cover)

# %% [markdown]
# > > Data Acquisition

# %%
# Load the libraries (numpy, pandas) for data analysis and data wrangling
import numpy as np
import pandas as pd

# Read the dataset 'ddiabetes-with-missing-values.csv'
df = pd.read_csv('data/diabetes-with-missing-values.csv')

# %%
# Sample function return a random sample of n items from an axis of object.
df.sample(n=10)
# Out:
#      pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 677          0.0     93.0       60.0      0.0      0.0  35.3  0.263   25
# 492          4.0     99.0       68.0     38.0      0.0  32.8  0.145   33
# 594          6.0    123.0       72.0     45.0    230.0  33.6  0.733   34
# 663          9.0    145.0       80.0     46.0    130.0  37.9  0.637   40
# 343          5.0    122.0       86.0      0.0      0.0  34.7  0.290   33
# 118          4.0      NaN       60.0     23.0      0.0  28.2  0.443   22
# 162          0.0    114.0       80.0     34.0    285.0  44.2  0.167   27
# 526          1.0     97.0       64.0     19.0     82.0  18.2  0.299   21
# 58           0.0    146.0       82.0      0.0      0.0  40.5  1.781   44
# 564          0.0     91.0       80.0      0.0      0.0  32.4  0.601   27
#
#      diabetes
# 677         0
# 492         0
# 594         0
# 663         1
# 343         0
# 118         0
# 162         0
# 526         0
# 58          0
# 564         0

# %%
# info function prints a concise summary of a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# pregnancies    767 non-null float64
# glucose        758 non-null float64
# diastolic      729 non-null float64
# triceps        767 non-null float64
# insulin        766 non-null float64
# bmi            765 non-null float64
# dpf            768 non-null float64
# age            768 non-null int64
# diabetes       768 non-null int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
# Print the description of the dataframe df
df.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   767.000000  758.000000  729.000000  767.000000  766.000000
# mean      3.846154  120.996042   68.772291   20.530639   79.916449
# std       3.371638   31.970780   19.633881   15.961811  115.357873
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.750000   80.000000   32.000000  127.750000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  765.000000  768.000000  768.000000  768.000000
# mean    31.975556    0.471876   33.240885    0.348958
# std      7.875099    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# 50%     32.000000    0.372500   29.000000    0.000000
# 75%     36.500000    0.626250   41.000000    1.000000
# max     67.100000    2.420000   81.000000    1.000000

# %% [markdown]
# > Analyzing Missingness Percentage

# %%
# Create a nullity DataFrame df_nullity
df_nullity = df.isnull()

# %%
# print nullity df_nullity
df_nullity.head(n=10)
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin    bmi    dpf    age  \
# 0        False    False      False    False    False  False  False  False
# 1        False    False      False    False    False  False  False  False
# 2        False    False      False    False    False  False  False  False
# 3        False    False      False    False    False  False  False  False
# 4        False    False      False    False    False  False  False  False
# 5        False    False      False    False    False  False  False  False
# 6        False    False      False    False    False  False  False  False
# 7        False    False      False    False    False  False  False  False
# 8        False    False      False    False    False  False  False  False
# 9        False    False      False    False    False  False  False  False
#
#    diabetes
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False

# %%
# Calculate total of missing values
print('Total Missing Values:\n', df_nullity.sum())
# Out:
# Total Missing Values:
#  pregnancies     1
# glucose        10
# diastolic      39
# triceps         1
# insulin         2
# bmi             3
# dpf             0
# age             0
# diabetes        0
# dtype: int64

# %%
# Calculate percentage of missing values
df_nullity_percent =  df_nullity.mean() * 100
print('Percentage of Missing Values:\n', df_nullity_percent)
# Out:
# Percentage of Missing Values:
#  pregnancies    0.130208
# glucose        1.302083
# diastolic      5.078125
# triceps        0.130208
# insulin        0.260417
# bmi            0.390625
# dpf            0.000000
# age            0.000000
# diabetes       0.000000
# dtype: float64

# %% [markdown]
# > Visualize Missingness

# %%
# Import missingno as msno
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# Set Solarize_Light2 style
plt.style.use('Solarize_Light2')

# %%
# Plot amount of missingness in the DataFrame
msno.bar(
    df,
    figsize=(24, 10),
    fontsize=16,
    labels=None,
    log=False,
    color='limegreen',
    inline=False,
    filter=None,
    n=0,
    p=0,
    sort=None,
    ax=None
)

plt.show()

# %% [markdown]
# > Plot the nullity matrix of df

# %%
# Plot nullity matrix of df
msno.matrix(
    df=df,
    filter=None,
    n=0,
    p=0,
    sort=None,
    figsize=(25, 10),
    width_ratios=(15, 1),
    color=(1,0,0),
    fontsize=16,
    labels=None,
    sparkline=True,
    inline=False,
    freq=None,
    ax=None,
)

plt.show()

# %%
# Sort diabetes dataframe df on 'diastolic'
sorted_values = df.sort_values(by=['diastolic'])

# Visualize the missingness summary of sorted
msno.matrix(
    sorted_values,
    filter=None,
    n=0,
    p=0,
    sort=None,
    figsize=(25, 10),
    width_ratios=(15, 1),
    color=(0,1,0),
    fontsize=16,
    labels=None,
    sparkline=True,
    inline=False,
    freq=None,
    ax=None,
)

plt.show()

# %% [markdown]
# > Correlations Between Missing Data (Missingness)
#
# > Remember we could find correlations between missing data and it helps us to gain a deeper understanding of the type of missing data.
# > It also provides suitable ways in which the missing values can be addressed.

# %%
# Plot missingness heatmap of diabetes DataFrame df
msno.heatmap(
    df,
    inline=False,
    filter=None,
    n=0,
    p=0,
    sort=None,
    figsize=(20, 12),
    fontsize=16,
    labels=True,
    cmap='gist_rainbow',
    vmin=-1,
    vmax=1,
    cbar=True,
    ax=None,
)

# Show plot
plt.show()

# %%
# Plot missingness dendrogram of diabetes DataFrame df
msno.dendrogram(
    df,
    method='average',
    filter=None,
    n=0,
    p=0,
    orientation=None,
    figsize=None,
    fontsize=16,
    inline=False,
    ax=None,
)

# Show plot
plt.show()

# %%
# Import IterativeImputer from fancyimpute
from fancyimpute import IterativeImputer

# Copy df to diabetes_mice_imputed
diabetes_mice_imputed = df.copy(deep=True)

# Initialize IterativeImputer
mice_imputer = IterativeImputer()

# Impute using fit_transform on df
diabetes_mice_imputed.iloc[:, :] = mice_imputer.fit_transform(df)
# Out:
# C:\DataScience\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Create a nullity DataFrame df_nullity from diabetes_mice_imputed
df_nullity = diabetes_mice_imputed.isnull()

# %%
# Calculate total of missing values
print('Total Missing Values:\n', df_nullity.sum())
# Out:
# Total Missing Values:
#  pregnancies    0
# glucose        0
# diastolic      0
# triceps        0
# insulin        0
# bmi            0
# dpf            0
# age            0
# diabetes       0
# dtype: int64
