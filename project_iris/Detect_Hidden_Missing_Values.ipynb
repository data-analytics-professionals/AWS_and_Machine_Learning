# %% [markdown]
# <h1> AWS and Machine Learning </h1>

# %% [markdown]
# > Data Cleaning - Strategies for Missing Values – Detect Hidden Missing Values and Convert into NULL Values

# %% [markdown]
# GitHub Link: https://github.com/data-analytics-professionals

# %%
# Set the Jyputer Notebook, width: 100% 
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from IPython.display import Image
cover = Image(filename="../project_iris/photos/Detect Hidden Missing Values .png")
display(cover)

# %%
# Load the libraries (numpy, pandas) for data analysis and data wrangling
import numpy as np
import pandas as pd

# Read the dataset 'Iris_Hidden_Missing_Values.csv'
df = pd.read_csv('data/Iris_Hidden_Missing_Values.csv')
print(df.head())
# Out:
#   sepal_length sepal_width petal_length petal_width        class
# 0            .         3.5          1.4         0.2  Iris-setosa
# 1          4.9           3          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4            5         3.6          1.4         0.2  Iris-setosa

# %%
# Sample function return a random sample of n items from an axis of object.
df.sample(n=10)
# Out:
#     sepal_length sepal_width petal_length petal_width            class
# 66           5.6           3          4.5         1.5  Iris-versicolor
# 120          6.9         3.2          5.7         2.3   Iris-virginica
# 91           6.1           3          4.6         1.4  Iris-versicolor
# 29           4.7           .          1.6         0.2      Iris-setosa
# 43             5         3.5          1.6         0.6      Iris-setosa
# 7              5         3.4            .         0.2      Iris-setosa
# 139          6.9         3.1          5.4         2.1   Iris-virginica
# 47           4.6         3.2          1.4         0.2      Iris-setosa
# 0              .         3.5          1.4         0.2      Iris-setosa
# 84           5.4           3          4.5         1.5  Iris-versicolor

# %%
# info function prints a concise summary of a DataFrame including the index dtype and column dtypes, non-null values and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null object
# sepal_width     150 non-null object
# petal_length    149 non-null object
# petal_width     149 non-null object
# class           150 non-null object
# dtypes: object(5)
# memory usage: 5.9+ KB

# %%
# Store unique values of 'sepal_length' column to 'sepal_length_unique'
sepal_length_unique = df.sepal_length.unique()

# %%
# Print the sorted values of sepal_length_unique
print(np.sort(sepal_length_unique))
# Out:
# ['.' '4.3' '4.4' '4.5' '4.6' '4.7' '4.8' '4.9' '5' '5.1' '5.2' '5.3' '5.4'
#  '5.5' '5.6' '5.7' '5.8' '5.9' '6' '6.1' '6.2' '6.3' '6.4' '6.5' '6.6'
#  '6.7' '6.8' '6.9' '7' '7.1' '7.2' '7.3' '7.4' '7.6' '7.7' '7.9']

# %% [markdown]
# > Replacing Hidden Missing Values

# %%
# Read the dataset 'Iris_Hidden_Missing_Values.csv' with na_values set to (.)
df = pd.read_csv('data/Iris_Hidden_Missing_Values.csv', na_values='.')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           NaN          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Print the info of college
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    145 non-null float64
# sepal_width     144 non-null float64
# petal_length    142 non-null float64
# petal_width     148 non-null float64
# class           150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# None
